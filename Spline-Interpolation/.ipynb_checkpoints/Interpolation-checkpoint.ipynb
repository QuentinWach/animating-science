# %% [markdown]
# ## Interpolierter Random Walk

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
plt.style.use("default")
plt.style.use("seaborn-dark")
plt.style.use("grayscale")

fig, ax = plt.subplots(figsize=(7,7), dpi=300)
fig.patch.set_facecolor('white')
plt.xticks([])
plt.yticks([])

# Startparameter
maxZeit  = 10
# Auflösung
res = 0.05

# Zeige die vergangenen Punkte
pastx = [0]
pasty = [0]

for frame in range(maxZeit):
    pastx.append(frame+1)
    pasty.append(pasty[frame] + (speed*np.random.random())*2-1)
    
cs = CubicSpline(pastx, pasty)
xs = np.arange(0,maxZeit+res,res)
ax.plot(xs, cs(xs))
ax.plot(pastx, pasty, "o", markersize=6)
plt.show()
